# %% [markdown]
# [Reorder Data in Log Files 문제 출처](https://leetcode.com/problems/reorder-data-in-log-files/)

# %% [markdown]
# You are given an array of **logs**. Each log is a space-delimited string of words, where the first word is the identifier.
#
# There are two types of logs:
# - **Letter-logs**: All words (except the identifier) consist of lowercase English letters.
# - **Digit-logs**: All words (except the identifier) consist of digits.
#
#
# Reorder these logs so that:
#
# 1. The letter-logs come before all digit-logs.
# 2. The letter-logs are sorted lexicographically by their contents. If their contents are the same, then sort them lexicographically by their identifiers.
# 3. The digit-logs maintain their relative ordering.
#
# Return the final order of the logs.

# %% [markdown]
# #### Example 1:

# %% [markdown]
# **Input**: logs = ["dig1 8 1 5 1","let1 art can","dig2 3 6","let2 own kit dig","let3 art zero"] <br>
# **Output**: ["let1 art can","let3 art zero","let2 own kit dig","dig1 8 1 5 1","dig2 3 6"] <br>
# **Explanation**:
# The letter-log contents are all different, so their ordering is "art can", "art zero", "own kit dig".
# The digit-logs have a relative order of "dig1 8 1 5 1", "dig2 3 6".

# %% [markdown]
# #### Example 2:

# %% [markdown]
# **Input**: logs = ["a1 9 2 3 1","g1 act car","zo4 4 7","ab1 off key dog","a8 act zoo"] <br>
# **Output**: ["g1 act car","a8 act zoo","ab1 off key dog","a1 9 2 3 1","zo4 4 7"]

# %% [markdown]
# #### Constraints:

# %% [markdown]
# - 1 <= logs.length <= 100
# - 3 <= logs[i].length <= 100
# - All the tokens of logs[i] are separated by a single space.
# - logs[i] is guaranteed to have an identifier and at least one word after the identifier.

# %%
class Solution:
    def reorderLogFiles(self, logs: List[str]) -> List[str]:
        letters, digits = [], []
        for log in logs:
            if log.split()[1].isdigit():
                digits.append(log)
            else:
                letters.append(log)
                
        # Sorting two keys by lambda representation
        letters.sort(key = lambda x: (x.split()[1:], x.split()[0]))
        return letters + digits

# %% [markdown]
# : 그대로 sort로 정렬을 하게 되면 인덱스 0을 기준으로 정렬되므로 리스트 컴프리헨션으로 이를 해결하였다.
#
# 아래는 실행 결과와 제출내역이다.

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20110831.jpg](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20110831.jpg)

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20110845.jpg](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20110845.jpg)
