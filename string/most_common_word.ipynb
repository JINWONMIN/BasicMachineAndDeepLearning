# %% [markdown]
# [Most Common Word 문제 출처](https://leetcode.com/problems/most-common-word/)

# %% [markdown]
# Given a string **paragraph** and a string array of the banned words banned, return the most frequent word that is not banned. It is **guaranteed** there is **at least one word** that is not banned, and that the answer is **unique**.
#
# The words in **paragraph are **case0insensitive** andthe answer should be returned in **lowercase**.

# %% [markdown]
# #### Example 1:

# %% [markdown]
# **Input**: paragraph = "Bob hit a ball, the hit BALL flew far after it was hit.", banned = ["hit"]
# Output: "ball" <br>
#
# **Output**: "ball" <br>
#
# **Explanation**:
# "hit" occurs 3 times, but it is a banned word.
# "ball" occurs twice (and no other word does), so it is the most frequent non-banned word in the paragraph.
# Note that words in the paragraph are not case sensitive,
# that punctuation is ignored (even if adjacent to words, such as "ball,"),
# and that "hit" isn't the answer even though it occurs more because it is banned.

# %% [markdown]
# #### Example 2:

# %% [markdown]
# **Input**: paragraph = "a.", banned = [] <br>
#
# **Output**: "a"

# %% [markdown]
# #### Constraints:

# %% [markdown]
# - 1 <= paragraph.length <= 1000
# - paragraph consists of English letters, space ' ', or one of the symbols: "!?',;.".
# - 0 <= banned.length <= 100
# - 1 <= banned[i].length <= 10
# - banned[i] consists of only lowercase English letters.

# %%
class Solution:
    def mostCommonWord(self, paragraph: str, banned: List[str]) -> str:
        words = [word for word in re.sub(r'[^\w]', ' ', paragraph)
                .lower().split()
                        if word not in banned]
        
        counts = collections.Counter(words)
        # 가장 흔하게 등장하는 단어의 첫 번째 인덱스 리턴
        return counts.most_common(1)[0][0]

# %% [markdown]
# : 정규표현식을 사용해 문자가 아닌 모든 문자를 공백으로 치환 후 소문자로 바꾸었다. 추가로 banned를 제외한 단어를 words에 추가하였다.
#
# counter 객체를 이용해 most_common(1)의 가장 흔하게 등장하는 첫 번째 인덱스를 리턴값으로 출력하였음.
#
# 아래는 결과 값과 메모리 사용 내역이다.

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20115551.jpg](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20115551.jpg)

# %% [markdown]
# ![%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20115600.jpg](attachment:%ED%99%94%EB%A9%B4%20%EC%BA%A1%EC%B2%98%202022-02-23%20115600.jpg)
